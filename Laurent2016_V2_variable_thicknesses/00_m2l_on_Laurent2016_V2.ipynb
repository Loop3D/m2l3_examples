# %% [markdown]
# <a href="https://colab.research.google.com/github/Loop3D/m2l3_examples/blob/main/inclined%20parallel%20stratigraphy/Synthetic_example_parallel_and_inclined_stratigraphy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install stuff if running on Colab
if 'google.colab' in str(get_ipython()):
    # !pip install git+https://github.com/Loop3D/map2model_cpp.git
    # !pip install git+https://github.com/Loop3D/map2loop.git
    # !pip install git+https://github.com/Loop3D/LoopStructural.git@v1.5.11
    # !pip install git+https://github.com/Loop3D/LoopProjectFile.git@0.0.26
    # !pip install lavavu-osmesa==1.8.60
    # !pip install meshio
    # !pip uninstall gdown -y

else:
      print('Not running on CoLab, nothing to do')
# Out:
# Collecting git+https://github.com/Loop3D/map2model_cpp.git
#   Cloning https://github.com/Loop3D/map2model_cpp.git to /tmp/pip-req-build-w7fswxyh
#   Running command git clone --filter=blob:none --quiet https://github.com/Loop3D/map2model_cpp.git /tmp/pip-req-build-w7fswxyh
#   Resolved https://github.com/Loop3D/map2model_cpp.git to commit 4a3e59528e99a0592bd5cc213ee0eaae559b9c8a
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/Loop3D/map2loop.git
#   Cloning https://github.com/Loop3D/map2loop.git to /tmp/pip-req-build-g35sqasy
#   Running command git clone --filter=blob:none --quiet https://github.com/Loop3D/map2loop.git /tmp/pip-req-build-g35sqasy
#   Resolved https://github.com/Loop3D/map2loop.git to commit 657b2802b822829e8d9218cad317f56330dfada0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (1.5.3)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (0.13.2)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (2.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (4.66.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (3.2.1)
# Requirement already satisfied: owslib in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (0.30.0)
# Requirement already satisfied: hjson in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (3.1.0)
# Requirement already satisfied: loopprojectfile in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (0.0.26)
# Requirement already satisfied: map2model in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (1.2.0)
# Requirement already satisfied: beartype in /usr/local/lib/python3.10/dist-packages (from map2loop==3.0.6) (0.17.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->map2loop==3.0.6) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas->map2loop==3.0.6) (24.0)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->map2loop==3.0.6) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->map2loop==3.0.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->map2loop==3.0.6) (2023.4)
# Requirement already satisfied: netCDF4>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from loopprojectfile->map2loop==3.0.6) (1.6.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from owslib->map2loop==3.0.6) (4.9.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from owslib->map2loop==3.0.6) (6.0.1)
# Requirement already satisfied: requests>=1.0 in /usr/local/lib/python3.10/dist-packages (from owslib->map2loop==3.0.6) (2.31.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas->map2loop==3.0.6) (1.16.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.5.4->loopprojectfile->map2loop==3.0.6) (1.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=1.0->owslib->map2loop==3.0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=1.0->owslib->map2loop==3.0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=1.0->owslib->map2loop==3.0.6) (2.0.7)
# Collecting git+https://github.com/Loop3D/LoopStructural.git@v1.5.11
#   Cloning https://github.com/Loop3D/LoopStructural.git (to revision v1.5.11) to /tmp/pip-req-build-osskp_nv
#   Running command git clone --filter=blob:none --quiet https://github.com/Loop3D/LoopStructural.git /tmp/pip-req-build-osskp_nv
#   Running command git checkout -q 0c5f59ddaa8bb53851112faed45386a99e3e5c01
#   Resolved https://github.com/Loop3D/LoopStructural.git to commit 0c5f59ddaa8bb53851112faed45386a99e3e5c01
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (1.11.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from LoopStructural==1.5.11) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LoopStructural==1.5.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LoopStructural==1.5.11) (2023.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->LoopStructural==1.5.11) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->LoopStructural==1.5.11) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->LoopStructural==1.5.11) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->LoopStructural==1.5.11) (1.16.0)
# Collecting git+https://github.com/Loop3D/LoopProjectFile.git@0.0.26
#   Cloning https://github.com/Loop3D/LoopProjectFile.git (to revision 0.0.26) to /tmp/pip-req-build-jtw5w6c1
#   Running command git clone --filter=blob:none --quiet https://github.com/Loop3D/LoopProjectFile.git /tmp/pip-req-build-jtw5w6c1
#   Running command git checkout -q c45f27c28394c99789c17d7c5c3a034854e62f75
#   Resolved https://github.com/Loop3D/LoopProjectFile.git to commit c45f27c28394c99789c17d7c5c3a034854e62f75
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: netCDF4>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from LoopProjectFile==0.0.26) (1.6.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from LoopProjectFile==0.0.26) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from LoopProjectFile==0.0.26) (1.5.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.5.4->LoopProjectFile==0.0.26) (1.6.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.5.4->LoopProjectFile==0.0.26) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LoopProjectFile==0.0.26) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->LoopProjectFile==0.0.26) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->LoopProjectFile==0.0.26) (1.16.0)
# Requirement already satisfied: lavavu-osmesa==1.8.60 in /usr/local/lib/python3.10/dist-packages (1.8.60)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from lavavu-osmesa==1.8.60) (1.25.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from lavavu-osmesa==1.8.60) (3.9.3)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.10/dist-packages (from lavavu-osmesa==1.8.60) (4.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->lavavu-osmesa==1.8.60) (4.0.3)
# Requirement already satisfied: jupyter-server>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.24.0)
# Requirement already satisfied: simpervisor>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.0.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->lavavu-osmesa==1.8.60) (6.3.3)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->lavavu-osmesa==1.8.60) (5.7.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (23.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (3.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (5.7.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (5.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (24.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.20.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.18.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.7.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp->lavavu-osmesa==1.8.60) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (4.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (4.19.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.18.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->lavavu-osmesa==1.8.60) (2.21)
# Requirement already satisfied: meshio in /usr/local/lib/python3.10/dist-packages (5.3.5)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from meshio) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from meshio) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->meshio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->meshio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->meshio) (0.1.2)
# Found existing installation: gdown 5.1.0
# Uninstalling gdown-5.1.0:
#   Successfully uninstalled gdown-5.1.0

# %%
# !pip install gdown
# data files in link below
# !gdown --folder https://drive.google.com/drive/folders/1182Po7WxlB8KHxvygstvwd1LboFyP8nR
# Out:
# Collecting gdown
#   Using cached gdown-5.1.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
# Successfully installed gdown-5.1.0
# Retrieving folder contents
# Processing file 11W0XmlITTVucwD_6QPYwpwTi2RDa59wY 500kibg_colours.csv
# Processing file 1762abrLrJqrXLJ72C6bgGLpezmMTA_4x DEM.tif
# Processing file 1VhEDshIQ-B-bOkRqDbUZyCne6LWkmXGu example.hjson
# Processing file 1RnCA1q2v7PKpIs_8z9nJPkC6z8yUFfth faults.cpg
# Processing file 1PigU5RvU8W4XblviWKSaiSt0-SWlARCL faults.dbf
# Processing file 1QanxYZ813l3ECVA7uD3XVF9ef5FQc-C4 faults.prj
# Processing file 1Nn_Q4qUxs3cuQx5lcUJpzj2g4VQvRnTD faults.qix
# Processing file 1QWtPkxaO2WmKpJls1gH8oujZMpWBTbpH faults.shp
# Processing file 15V-uounbE6xOsZ9SOxmcH6Tup1JWVjBI faults.shx
# Processing file 1ys0Fr_m1TOrtaS584lAbabHtwuYo7mum geology.cpg
# Processing file 1n4e5zCeDBh-LBi6ae1v98i40Fn0kps9V geology.dbf
# Processing file 1PolkO764hmXOc1veiGECqFnfn_u_DYXZ geology.prj
# Processing file 1oXr5bZvMPOUoBqlLyFwHpS04j0gyI54e geology.shp
# Processing file 1H1PDiBVQQPe28dIjRGVCzKVh7XvjdEZh geology.shx
# Processing file 1pUg8RVZUnzkGOXLlqYWsJVVM4qmshHiN ROI.cpg
# Processing file 1WPNMyIH3yjgiN4NoJNY5aIq2tVHFqT2E ROI.dbf
# Processing file 1IuDkR_z-npM0Umxuwd9MVretrqP3Unxz ROI.prj
# Processing file 1NtrWutbXKn-O9Fn6CETcEXBROF8ixvVs ROI.shp
# Processing file 1gOHDbDIDNB3P_MYSzUugifP-cPqAty2A ROI.shx
# Processing file 1v_ohm1wPMkeIaxE7qgumQhumjLP6chQx structures.cpg
# Processing file 1dhixTyVElXtcxEBXoNcVhxqZRblga7ut structures.dbf
# Processing file 1NH0V5BnOVaCXJ1qhCOTahWPR16ERbBai structures.prj
# Processing file 1iDdw7lmMXqJbP2n6w1N6PH1AfPSMuxoH structures.shp
# Processing file 1GL9mbrEYw3c4PnGBCHWhFwyoK65aUsg6 structures.shx
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=11W0XmlITTVucwD_6QPYwpwTi2RDa59wY
# To: /content/Laurent2016_V2/500kibg_colours.csv
# 100% 317/317 [00:00<00:00, 1.08MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1762abrLrJqrXLJ72C6bgGLpezmMTA_4x
# To: /content/Laurent2016_V2/DEM.tif
# 100% 49.2k/49.2k [00:00<00:00, 55.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VhEDshIQ-B-bOkRqDbUZyCne6LWkmXGu
# To: /content/Laurent2016_V2/example.hjson
# 100% 4.02k/4.02k [00:00<00:00, 8.17MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RnCA1q2v7PKpIs_8z9nJPkC6z8yUFfth
# To: /content/Laurent2016_V2/faults.cpg
# 100% 5.00/5.00 [00:00<00:00, 19.2kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1PigU5RvU8W4XblviWKSaiSt0-SWlARCL
# To: /content/Laurent2016_V2/faults.dbf
# 100% 98.0/98.0 [00:00<00:00, 330kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QanxYZ813l3ECVA7uD3XVF9ef5FQc-C4
# To: /content/Laurent2016_V2/faults.prj
# 100% 403/403 [00:00<00:00, 1.64MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Nn_Q4qUxs3cuQx5lcUJpzj2g4VQvRnTD
# To: /content/Laurent2016_V2/faults.qix
# 100% 60.0/60.0 [00:00<00:00, 226kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QWtPkxaO2WmKpJls1gH8oujZMpWBTbpH
# To: /content/Laurent2016_V2/faults.shp
# 100% 100/100 [00:00<00:00, 317kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15V-uounbE6xOsZ9SOxmcH6Tup1JWVjBI
# To: /content/Laurent2016_V2/faults.shx
# 100% 100/100 [00:00<00:00, 139kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ys0Fr_m1TOrtaS584lAbabHtwuYo7mum
# To: /content/Laurent2016_V2/geology.cpg
# 100% 5.00/5.00 [00:00<00:00, 24.4kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1n4e5zCeDBh-LBi6ae1v98i40Fn0kps9V
# To: /content/Laurent2016_V2/geology.dbf
# 100% 1.44k/1.44k [00:00<00:00, 6.80MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1PolkO764hmXOc1veiGECqFnfn_u_DYXZ
# To: /content/Laurent2016_V2/geology.prj
# 100% 403/403 [00:00<00:00, 1.98MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oXr5bZvMPOUoBqlLyFwHpS04j0gyI54e
# To: /content/Laurent2016_V2/geology.shp
# 100% 17.4k/17.4k [00:00<00:00, 45.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1H1PDiBVQQPe28dIjRGVCzKVh7XvjdEZh
# To: /content/Laurent2016_V2/geology.shx
# 100% 204/204 [00:00<00:00, 990kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1pUg8RVZUnzkGOXLlqYWsJVVM4qmshHiN
# To: /content/Laurent2016_V2/ROI.cpg
# 100% 5.00/5.00 [00:00<00:00, 21.9kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WPNMyIH3yjgiN4NoJNY5aIq2tVHFqT2E
# To: /content/Laurent2016_V2/ROI.dbf
# 100% 77.0/77.0 [00:00<00:00, 361kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1IuDkR_z-npM0Umxuwd9MVretrqP3Unxz
# To: /content/Laurent2016_V2/ROI.prj
# 100% 403/403 [00:00<00:00, 1.79MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NtrWutbXKn-O9Fn6CETcEXBROF8ixvVs
# To: /content/Laurent2016_V2/ROI.shp
# 100% 236/236 [00:00<00:00, 1.16MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gOHDbDIDNB3P_MYSzUugifP-cPqAty2A
# To: /content/Laurent2016_V2/ROI.shx
# 100% 108/108 [00:00<00:00, 546kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1v_ohm1wPMkeIaxE7qgumQhumjLP6chQx
# To: /content/Laurent2016_V2/structures.cpg
# 100% 5.00/5.00 [00:00<00:00, 19.6kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dhixTyVElXtcxEBXoNcVhxqZRblga7ut
# To: /content/Laurent2016_V2/structures.dbf
# 100% 41.7k/41.7k [00:00<00:00, 60.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NH0V5BnOVaCXJ1qhCOTahWPR16ERbBai
# To: /content/Laurent2016_V2/structures.prj
# 100% 403/403 [00:00<00:00, 2.24MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1iDdw7lmMXqJbP2n6w1N6PH1AfPSMuxoH
# To: /content/Laurent2016_V2/structures.shp
# 100% 12.9k/12.9k [00:00<00:00, 32.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GL9mbrEYw3c4PnGBCHWhFwyoK65aUsg6
# To: /content/Laurent2016_V2/structures.shx
# 100% 3.75k/3.75k [00:00<00:00, 16.2MB/s]
# Download completed

# %%
import os
import time
import numpy as np
from osgeo import gdal
import pandas as pd
from datetime import datetime

from map2loop.project import Project
from map2loop.m2l_enums import VerboseLevel

from map2loop.m2l_enums import Datatype
from map2loop.sampler import SamplerSpacing, SamplerDecimator

import LoopStructural
import LoopProjectFile as LPF
from LoopStructural import GeologicalModel
from LoopStructural.visualisation import LavaVuModelViewer
from LoopStructural.modelling.input.project_file import LoopProjectfileProcessor as LPFProcessor
# Out:
# WARNING: 2024-03-20 02:28:44,216: __init__.py:75 -- Can't import surfepy - to install "pip install surfe"
# WARNING: 2024-03-20 02:28:44,218: __init__.py:77 -- Using experimental interpolators: P1Interpolator and P2Interpolator

# %%
bounding_box = {
    "minx": 0,
    "miny": 0,
    "maxx": 10000,
    "maxy": 10000,
    "base": 0,
    "top": -5000,
}

nowtime=datetime.now().isoformat(timespec='minutes')
model_name=nowtime.replace(":","-").replace("T","-")
loop_project_filename = os.path.join(model_name, "local_source.loop3d")

# %%
proj = Project(
    geology_filename = './Laurent2016_V2/geology.shp',
    fault_filename = "./Laurent2016_V2/faults.shp",
    fold_filename = "./Laurent2016_V2/faults.shp",
    structure_filename = "./Laurent2016_V2/structures.shp",
    dtm_filename = './Laurent2016_V2/DEM.tif',
    config_filename = './Laurent2016_V2/example.hjson',
    clut_filename = './Laurent2016_V2/500kibg_colours.csv',
    clut_file_legacy = True,
    verbose_level = VerboseLevel.NONE,
    tmp_path = model_name,
    working_projection = "EPSG:7854",
    bounding_box = bounding_box,
    loop_project_filename = loop_project_filename
)
# Out:
# Unused keys from legacy format ['msc', 'msn', 'mst', 'mtc', 'mscm', 'mcom', 'minf', 'fdipdir_flag', 'deposit_dist']
# Datatype FAULT_ORIENTATION is not set and so cannot be loaded

# %%
# Set to only take every second orientation observation (0 or 1 means take all observations)
proj.set_sampler(Datatype.STRUCTURE, SamplerDecimator(0))
proj.set_sampler(Datatype.GEOLOGY, SamplerSpacing(100.0))

# %%
# Or you can run map2loop and pre-specify the stratigraphic column
column = [
    # youngest
    'Litho_K',
    'Litho_J',
    'Litho_I',
    'Litho_H',
    'Litho_G',
    'Litho_F',
    'Litho_E',
    'Litho_D',
    'Litho_C',
    'Litho_B',
    'Litho_A',
    # oldest
]

column
proj.run_all(user_defined_stratigraphic_column=column)

LPFilename = loop_project_filename
projFile = LPF.ProjectFile(LPFilename)
processedData = LPFProcessor(projFile)
# Out:
# Cannot calculate thickness between Litho_B and Litho_A

# %%
foliation_params = {
    'interpolatortype':'FDI' , # 'interpolatortype':'PLI',
    'nelements':1e5,  # how many tetras/voxels
    # 'regularisation':[5,5,10],
    'cpw': 1,
    'npw':0.5,
    'gpw':0.6,
    'solver': 'pyamg'
}

model = LoopStructural.GeologicalModel.from_processor(processedData)
model.update()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from google.colab import output
output.enable_custom_widget_manager()

from LoopStructural.visualisation import LavaVuModelViewer

view = LavaVuModelViewer(model)
# view.nsteps = [200, 200, 500]
view.add_data(model['sg'])
# view.add_model()
view.add_model_surfaces()

view.rotation = [-56.68132781982422, 42.125144958496094, -2.6206510066986084]
view.display()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# <img src='data:image/png;base64,...'>

# %%
proj.map_data.get_map_data(Datatype.GEOLOGY).plot()
# Out:
# <Axes: >

# %%
proj.map_data.get_map_data(Datatype.STRUCTURE)
# Out:
#                       geometry  DIPDIR   DIP  OVERTURNED  BEDDING   ID
# 37    POINT (9323.566 276.265)    81.0  36.6       False     True    0
# 179   POINT (8919.234 418.145)    80.0  33.5       False     True    1
# 149   POINT (8638.030 423.452)    82.0  33.5       False     True    2
# 425   POINT (9228.271 579.794)    79.0  82.1       False     True    3
# 81    POINT (9467.220 642.335)    85.0  67.3       False     True    4
# ..                         ...     ...   ...         ...      ...  ...
# 336  POINT (6926.064 9562.854)    41.7  27.9       False     True  451
# 139  POINT (6866.442 9644.167)    20.2  45.5       False     True  452
# 125  POINT (5991.475 9725.806)    41.6  53.6       False     True  453
# 335  POINT (6452.428 9747.131)    26.0  46.8       False     True  454
# 391  POINT (6596.813 9921.138)    26.0  46.8       False     True  455
#
# [456 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(proj.geology_samples['X'], proj.geology_samples['Y'], c= proj.geology_samples['ID'])

# %%
proj.get_thickness_calculator()
# Out:
# 'ThicknessCalculatorAlpha'

# %%
processedData.thicknesses
# Out:
# {'Litho_K': 633.2278994502698,
#  'Litho_J': 399.5020797053674,
#  'Litho_I': 633.1205240580159,
#  'Litho_H': 499.33969830851095,
#  'Litho_G': 56.48722824024881,
#  'Litho_F': 877.7636565169825,
#  'Litho_E': 0.0,
#  'Litho_D': 1383.8560186561074,
#  'Litho_C': 582.5260906666551,
#  'Litho_B': 633.2278994502698,
#  'Litho_A': 633.2278994502698}
